# %%
word = input("Enter the word : " )
lenth = int(input("Enter the length of the word in numbers : "))
if len(word) == lenth :
            print("correct  ")
else :
            print("wrong guess ")
# Out:
# Enter the word :  virubha
# Enter the length of the word in numbers :  7
# correct
