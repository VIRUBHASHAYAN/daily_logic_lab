# %% [markdown]
# ### All List Functions

# %%
items_to_buy = ['apple','orange','grapes','banana','jackfruit']

# %%
items_to_buy.append('mango')

# %%
items_to_buy
# Out:
# ['apple', 'orange', 'grapes', 'banana', 'jackfruit', 'mango']

# %%
# so append is used to add the element at the end of the list

# %%
items_to_buy.clear()

# %%
items_to_buy
# Out:
# []

# %%
# clear is used to make the list empty

# %%
items_to_buy = ['apple','orange','grapes','banana','jackfruit']

# %%
a=items_to_buy.copy()

# %%
a[1]
# Out:
# 'orange'

# %%
# copy method is used to make a copy of a list

# %%
items_to_buy = ['apple','orange','grapes','banana','jackfruit']

# %%
items_to_buy.count('mango')
# Out:
# 0

# %%
items_to_buy.count('apple')
# Out:
# 1

# %%
# so here count is used to count the specific value in the list

# %%
items_to_buy.extend(cars_name )
items_to_buy
# Out:
# ['apple',
#  'orange',
#  'grapes',
#  'banana',
#  'jackfruit',
#  'bmw',
#  'benz',
#  'rr',
#  'bugati',
#  'bmw',
#  'benz',
#  'rr',
#  'bugati']

# %%
cars_name = ['bmw','benz','rr','bugati']

# %%
# extend is used to store more value at the end of the list

# %%
items_to_buy = ['apple','orange','grapes','banana','jackfruit']

# %%
items_to_buy.index('banana')
# Out:
# 3

# %%
# to find a particullar elements index we use the index function

# %%
items_to_buy.insert(1,"carrot")

# %%
items_to_buy
# Out:
# ['apple', 'carrot', 'orange', 'grapes', 'banana', 'jackfruit']

# %%
# to add a element in the specific index we use the insert function

# %%
items_to_buy = ['apple','orange','grapes','banana','jackfruit']

# %%
items_to_buy.pop(1)
# Out:
# 'orange'

# %%
items_to_buy
# Out:
# ['apple', 'grapes', 'banana', 'jackfruit']

# %%
# here pop is used to based on the index its remove the value in the list

# %%
items_to_buy = ['apple','orange','grapes','banana','jackfruit']

# %%
items_to_buy.remove('orange')

# %%
items_to_buy
# Out:
# ['apple', 'grapes', 'banana', 'jackfruit']

# %%
# it removes the value based on the exact name of it

# %%
items_to_buy = ['apple','orange','grapes','banana','jackfruit']

# %%
items_to_buy.reverse()

# %%
items_to_buy
# Out:
# ['jackfruit', 'banana', 'grapes', 'orange', 'apple']

# %%
# when we want to reverse the elements we use here the reverse function

# %%
items_to_buy = ['apple','orange','grapes','banana','jackfruit']

# %%
items_to_buy.sort()

# %%
items_to_buy
# Out:
# ['apple', 'banana', 'grapes', 'jackfruit', 'orange']

# %%
# sort is used to sorting based on the alphabets

# %% [markdown]
# #### ------THE END OF THE LIST FUNCTIONS-------

# %%
items_to_buy = ('apple','mango','orange','grapes','carrot','beetroot','beetroot',1,2)

# %%
items_to_buy
# Out:
# ('apple', 'mango', 'orange', 'grapes', 'carrot', 'beetroot', 'beetroot', 1, 2)

# %%
items_to_buy.count('beetroot')
# Out:
# 2

# %%
# Tuples allows only 2 functions count,index and all the built-in functions len,

# %%
items_to_buy.index(1)
# Out:
# 7

# %%
# index is used to retrive the values based on the index

# %%
items_to_buy[0:6]
# Out:
# ('apple', 'mango', 'orange', 'grapes', 'carrot', 'beetroot')

# %% [markdown]
# #### ------THE END ------

# %%
my_products={'speaker','mouse','pc','bluetooth','wire','charger','charger'} # duplicates not allowed

# %%
type(my_products)
# Out:
# set

# %%
my_products.add('mobile')

# %%
my_products
# Out:
# {'bluetooth', 'charger', 'mobile', 'mouse', 'pc', 'speaker', 'wire'}

# %%
my_products
# Out:
# {'bluetooth', 'charger', 'mobile', 'mouse', 'pc', 'speaker', 'wire'}

# %%
# when we want to add a items in a set we use add funtion

# %%
my_products.clear()

# %%
my_products
# Out:
# set()

# %%
# clear is used to make the set empty

# %%
my_products={'speaker','mouse','pc','bluetooth','wire','charger','charger'}

# %%
a = my_products.copy()

# %%
a
# Out:
# {'bluetooth', 'charger', 'mouse', 'pc', 'speaker', 'wire'}

# %%
# so copy function is used to make copy of set.

# %%
my_products.update([5,6])

# %%
my_products
# Out:
# {5, 6, 'bluetooth', 'charger', 'mouse', 'pc', 'speaker', 'wire'}

# %%
# update in sets is used to add multiple elements in the sets

# %%
 vehicles = {'car','bike','lorry','bus','train','flight'}
my_production= {'bus','sweet','current'}
vehicles.difference(my_production)
# Out:
# {'bike', 'car', 'flight', 'lorry', 'train'}

# %%
# basically difference do the a - b work

# %%
vehicles = {'car','bike','lorry','bus','train','flight'}
my_production= {'bus','sweet','current'}
vehicles.difference_update(my_production)
vehicles
# Out:
# {'bike', 'car', 'flight', 'lorry', 'train'}

# %%
# so here which is the content that present in both vehicle and my_production that should be removed

# %%
vehicles = {'car','bike','lorry','bus','train','flight'}
my_production= {'bus','sweet','current'}
vehicles.discard('gh')
vehicles.discard('car')
vehicles
# Out:
# {'bike', 'bus', 'flight', 'lorry', 'train'}

# %%
# discord is used to remove the element even that element is not in the vehicle discord not shows error.

# %%
First_exam_marks = {'45','37','56','49','55'}
second_exam_marks = {'89','37','67','49','15'}
First_exam_marks.intersection(second_exam_marks)
# Out:
# {'37', '49'}

# %%
# intersect is used to return elements that are present in both a and b

# %%
First_exam_marks = {'45','37','56','49','55'}
second_exam_marks = {'89','37','67','49','15'}
First_exam_marks.intersection_update(second_exam_marks)
First_exam_marks
# Out:
# {'37', '49'}

# %%
# here intersect_update is used to update a value to a with intersect elements of a and b

# %%
First_exam_marks = {'45','37','56','49','55'}
second_exam_marks = {'89','37','67','49','15'}
First_exam_marks.isdisjoint(second_exam_marks)
# Out:
# False

# %%
# is _ disjoint is used to asking is set a and set b have any commen elements if true then ther is no common else common elements are there

# %%
First_exam_marks = {'45','37','56','49','55'}
second_exam_marks = {'89','37','67','49','15','45','37','56','49','55'}
First_exam_marks.issubset(second_exam_marks)
# Out:
# True

# %%
# is_subset is used to check , is a present in b

# %%
First_exam_marks = {'45','37','56','49','55'}
second_exam_marks = {'89','37','67','49','15','45','37','56','49','55'}
second_exam_marks.issuperset(First_exam_marks)
# Out:
# True

# %%
# is_superset is used to check all values of a which are located in b also

# %%
First_exam_marks = {'45','37','56','49','55'}
second_exam_marks = {'89','37','67','49','15','45','37','56','49','55'}
second_exam_marks.pop()
# Out:
# '55'

# %%
# in set pop takes 0 arguments so its pop random values

# %%
First_exam_marks = {'45','37','56','49','55'}
second_exam_marks = {'89','37','67','49','15','45','37','56','49','55'}
second_exam_marks.remove("55")
second_exam_marks
# Out:
# {'15', '37', '45', '49', '56', '67', '89'}

# %%
# if we use remove that element must be inside the sets else error occurs

# %%
First_exam_marks = {'45','37','56','49','55'}
second_exam_marks = {'89','37','67','49','15','45','37','56','49','55'}
second_exam_marks.symmetric_difference(First_exam_marks)
# Out:
# {'15', '67', '89'}

# %%
# semmetric difference shows without common elements

# %%
First_exam_marks = {'45','37','56','49','55'}
second_exam_marks = {'89','37','67','49','15','45','37','56','49','55'}
second_exam_marks.symmetric_difference_update(First_exam_marks)
second_exam_marks
# Out:
# {'15', '67', '89'}

# %%
# here the semtric diference update to the a

# %%
First_exam_marks = {'45','37','56','49','55'}
second_exam_marks = {'89','37','67','49','15','45','37','56','49','55'}
second_exam_marks.union(second_exam_marks)
# Out:
# {'15', '37', '45', '49', '55', '56', '67', '89'}

# %%
# union is used to join 2 sets

# %%
First_exam_marks = {'45','37','56','49','55'}
First_exam_marks.update(['78','8'])
First_exam_marks
# Out:
# {'37', '45', '49', '55', '56', '78', '8'}

# %%
# update is used to insert the element in sets

# %% [markdown]
# #### -------- The End ---------

# %%
user_access = {"praveen":123 ,"ragu":234,"ramu":879}

# %%
type(user_access )
# Out:
# dict

# %%
user_access.values()
# Out:
# dict_values([123, 234, 879])

# %%
# values returns all the key's value in the dictionary

# %%
user_access.get("ragu")
# Out:
# 234

# %%
# in dictionaries get function is used to get the values based on the keys

# %%
user_access.copy()
# Out:
# {'praveen': 123, 'ragu': 234, 'ramu': 879}

# %%
# copy is used to make copy of the dictionaries

# %%
user_access.items()
# Out:
# dict_items([('praveen', 123), ('ragu', 234), ('ramu', 879)])

# %%
# items return total key pair of the dict

# %%
user_access.keys()
# Out:
# dict_keys(['praveen', 'ragu', 'ramu'])

# %%
# keys will return all the keys present in the dictionary

# %%
user_access.pop("praveen")
# Out:
# 123

# %%
user_access
# Out:
# {'ragu': 234, 'ramu': 879}

# %%
# so here that the pop is used to remove the element based on the key then shows the value

# %%
user_access.popitem()
# Out:
# ('ramu', 879)

# %%
user_access
# Out:
# {'ragu': 234}

# %%
# remove last added element in the dict

# %%
user_access.setdefault("chandru",378)
user_access
# Out:
# {'ragu': 234, 'chandru': 378}

# %%
# used to modify the dictionary even the element not present in the dict

# %%
user_access.update({"chandru" : 364})

# %%
user_access
# Out:
# {'ragu': 234, 'chandru': 364}

# %%
# used to update and modify the sets

# %%
user_access.values()
# Out:
# dict_values([234, 364])

# %%
# it return values of the keys in the dict

# %% [markdown]
# #### ------- The End ---------

# %% [markdown]
# ## Task 2

# %%
import pandas as pd

# %%
admin_password = {"ram": 506, "john": 412, "dilip": 534, "lalith": 705}
Table = pd.DataFrame(admin_password.items(), columns=['Name', 'Password'])
print(Table)
# Out:
#      Name  Password
# 0     ram       506
# 1    john       412
# 2   dilip       534
# 3  lalith       705
