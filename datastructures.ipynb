# %% [markdown]
# ## Concept of list
# ### * here i can get mulitiple inputs in a structured way
#     * it works in 1D way  if fully rows(or) fully coloumn
#     *it accepts float,int all so it is hetrogeneous datastructure

# %%
store=["pen","pencil","scale","slade"] #here i can get multiple inputs

# %%
store
# Out:
# ['pen', 'pencil', 'scale', 'slade']

# %%
type(store)
# Out:
# list

# %%
store=["pen","pencil","scale","slade","pencil"]

# %%
store
# Out:
# ['pen', 'pencil', 'scale', 'slade', 'pencil']

# %% [markdown]
# #### so list accepts duplicates or repeated values

# %%
print(store[2])#here we use indexing [] concept this is not only for list
# Out:
# scale

# %%
store[-4:-2]
# Out:
# ['pencil', 'scale']

# %%
store[1]="eraser" #so here we can change the value so it is mutable

# %%
print(store)
# Out:
# ['pen', 'eraser', 'scale', 'slade', 'pencil']

# %% [markdown]
# ## sets datastructures

# %%
store_1= set()

# %%
type(store_1)
# Out:
# set

# %%
store_1={"pen","pencil","scale","slade","pencil"}

# %%
store_1
# Out:
# {'pen', 'pencil', 'scale', 'slade'}

# %%
store_1[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 store_1[1]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ### 'set' object is not subscriptable
#   -- so we can't indexing and slicing
#   -- it is mutable

# %%
store_1.add("sharpner")

# %%
store_1
# Out:
# {'pen', 'pencil', 'scale', 'sharpner', 'slade'}

# %%
store_1.update()

# %%
store_1
# Out:
# {'pen', 'pencil', 'scale', 'sharpner', 'slade'}

# %%
store_1.add("box")

# %%
store_1
# Out:
# {'box', 'pen', 'pencil', 'scale', 'sharpner', 'slade'}

# %%
store_1.discard("sharpner")

# %%
store_1
# Out:
# {'box', 'pen', 'pencil', 'scale', 'slade'}

# %% [markdown]
# ### TUPLES

# %% [markdown]
# * it is hertrogenious
# * *it is accept duplicates
# * it can index and slicing the elements but it cant change
# * it is immutable( #we can see the element but we cant change that)

# %%
flower_shop=()

# %%
type(flower_shop)
# Out:
# tuple

# %%
flower_shop=('rose', 'jasmine', 'lavendar', 'hibicus', 'sunflower')

# %%
flower_shop[-4:-1]
# Out:
# ('jasmine', 'lavendar', 'hibicus')

# %%
flower_shop["rose"]="pk"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 flower_shop["rose"]="pk"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## dictionary

# %%
## it is called key value pair datastructure
##it allows the duplicate(key) but it is updated by the second entry

# %%
flower_shop_1={'rose':[3,4], 'jasmine':[5], 'lavendar':[7], 'hibicus':[3], 'sunflower':[1],"rose":[8],"rose":[4]}

# %%
type(flower_shop_1)
# Out:
# dict

# %%
flower_shop_1
# Out:
# {'rose': [4],
#  'jasmine': [5],
#  'lavendar': [7],
#  'hibicus': [3],
#  'sunflower': [1]}

# %%
import pandas as pd

# %%
pd.DataFrame(flower_shop_1)
# Out:
#    rose  jasmine  lavendar  hibicus  sunflower
# 0     4        5         7        3          1

# %%
student_mark={"name":['viru','bha','sha','yan'],"marks":[20,30,40,50]}

# %%
pd.DataFrame(student_mark)
# Out:
#    name  marks
# 0  viru     20
# 1   bha     30
# 2   sha     40
# 3   yan     50

# %% [markdown]
# # The end
