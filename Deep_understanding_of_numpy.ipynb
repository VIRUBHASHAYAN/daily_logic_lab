# %%
import numpy as np
import time

# %%
size = 10000
start_time_list = time.time()
list_1 = list(range(size))
list_2 = list(range(size))
result = [list_1[i]+ list_2[i] for i in range(size)]
end_time_list = time.time() - strat_time
stat_time_arr = time.time()
arr_1 = np.array(range(size))
arr_2 = np.array(range(size))
#print(arr_1 + arr_2)
end_time_arr = time.time() - stat_time_arr
print(f"{end_time_list:.2f} This is the end time of list")
print(f"{end_time_arr:.2f} This is the end time of numpy")
print(f"{end_time_list/end_time_arr:.2f}X This is the Time numpy faster than list")
# Out:
# 631.55 This is the end time of list
# 0.01 This is the end time of numpy
# 44201.18X This is the Time numpy faster than list
